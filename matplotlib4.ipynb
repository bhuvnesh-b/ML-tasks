# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
expenses = [23435,12432,12342,3423]
explabels = ["rent", "fuel" , "food" , "bills"]
plt.pie(expenses,labels=explabels , radius=2 ,autopct = '%0.0f%%', shadow=True ,explode=[.1,.1,.1,0] , startangle=90)

plt.show()
